# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Ecommerce_Sales_Dataset.csv')

# %%
data
# Out:
#                                  Order ID           Product Name  \
# 0    1bb284ac-3c42-4219-aec4-24be2ff6cb91                  Shoes
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 Laptop
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            Smart Watch
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           Refrigerator
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         Vacuum Cleaner
# ..                                    ...                    ...
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  Machine Learning Book
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           Mobile Phone
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  Data Science Handbook
# 498  fdd68272-859d-46f6-a672-5e59e876e407        Washing Machine
# 499  41364d72-9763-4bd7-bd9b-4da70e7e242d                    NaN
#
#             Category    Price  Quantity  Order Date  Customer ID  \
# 0           Clothing      NaN         7  2023-11-05         6901
# ...

# %% [markdown]
# ## Understand the Data

# %%
data.head()
# Out:
#                                Order ID    Product Name         Category  \
# 0  1bb284ac-3c42-4219-aec4-24be2ff6cb91           Shoes         Clothing
# 1  275052d1-0592-40e0-8327-25019a3f99d3          Laptop      Electronics
# 2  7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d     Smart Watch      Electronics
# 3  5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6    Refrigerator  Home Appliances
# 4  eaeac001-bb18-4cbb-b490-1d407a03c886  Vacuum Cleaner  Home Appliances
#
#      Price  Quantity  Order Date  Customer ID                Country
# 0      NaN         7  2023-11-05         6901        Solomon Islands
# 1   505.07         9  2023-02-22         2369                  India
# 2  2206.52         1  2023-05-19         3187                  Nepal
# 3   457.76         7  2023-03-04         5608  Palestinian Territory
# 4  1203.32         8  2023-05-30         9875                Bahrain

# %%
data.tail()
# Out:
#                                  Order ID           Product Name  \
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  Machine Learning Book
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           Mobile Phone
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  Data Science Handbook
# 498  fdd68272-859d-46f6-a672-5e59e876e407        Washing Machine
# 499  41364d72-9763-4bd7-bd9b-4da70e7e242d                    NaN
#
#             Category    Price  Quantity  Order Date  Customer ID      Country
# 495            Books  2321.77         3  2023-02-17         4683      Uruguay
# 496      Electronics  1728.35         2  2023-06-04         6152     Maldives
# 497            Books  4822.10         3  2023-12-19         5745       Uganda
# 498  Home Appliances  3293.29        10  2023-04-01         6733  Switzerland
# 499           Beauty      NaN         9  2023-02-08         9374   Montserrat

# %%
data.shape
# Out:
# (500, 8)

# %%
data.describe()
# Out:
#              Price    Quantity  Customer ID
# count   472.000000  500.000000   500.000000
# mean   2506.492627    5.426000  5499.292000
# std    1438.151429    2.846177  2576.667803
# min     209.250000    1.000000  1012.000000
# 25%    1217.272500    3.000000  3354.750000
# 50%    2417.560000    5.000000  5570.500000
# 75%    3707.002500    8.000000  7778.500000
# max    4995.160000   10.000000  9988.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      500 non-null    object
#  1   Product Name  472 non-null    object
#  2   Category      500 non-null    object
#  3   Price         472 non-null    float64
#  4   Quantity      500 non-null    int64
#  5   Order Date    500 non-null    object
#  6   Customer ID   500 non-null    int64
#  7   Country       500 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 31.4+ KB

# %%
data.columns
# Out:
# Index(['Order ID', 'Product Name', 'Category', 'Price', 'Quantity',
#        'Order Date', 'Customer ID', 'Country'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Order ID         object
# Product Name     object
# Category         object
# Price           float64
# Quantity          int64
# Order Date       object
# Customer ID       int64
# Country          object
# dtype: object

# %% [markdown]
# ## Handle Missing Values

# %%
data.isnull().sum()
# Out:
# Order ID         0
# Product Name    28
# Category         0
# Price           28
# Quantity         0
# Order Date       0
# Customer ID      0
# Country          0
# dtype: int64

# %%
# drop missing Values for Row
data=data.dropna()

# %%
# drop missing values for columns
data.dropna(axis=1)
# Out:
#                                  Order ID           Product Name  \
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 Laptop
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            Smart Watch
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           Refrigerator
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         Vacuum Cleaner
# 6    23d02906-c09f-428a-bc4c-6e5fc711997c                Shampoo
# ..                                    ...                    ...
# 494  dadeb50b-5778-423d-a467-1f2d667044d6                Shampoo
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  Machine Learning Book
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           Mobile Phone
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  Data Science Handbook
# 498  fdd68272-859d-46f6-a672-5e59e876e407        Washing Machine
#
#             Category    Price  Quantity  Order Date  Customer ID  \
# 1        Electronics   505.07         9  2023-02-22         2369
# ...

# %% [markdown]
# ## Fill missing values:

# %%
# fill the missing values (0)
data.fillna(0)
# Out:
#                                  Order ID           Product Name  \
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 Laptop
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            Smart Watch
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           Refrigerator
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         Vacuum Cleaner
# 6    23d02906-c09f-428a-bc4c-6e5fc711997c                Shampoo
# ..                                    ...                    ...
# 494  dadeb50b-5778-423d-a467-1f2d667044d6                Shampoo
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  Machine Learning Book
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           Mobile Phone
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  Data Science Handbook
# 498  fdd68272-859d-46f6-a672-5e59e876e407        Washing Machine
#
#             Category    Price  Quantity  Order Date  Customer ID  \
# 1        Electronics   505.07         9  2023-02-22         2369
# ...

# %%
# fill the nissing value for mean,max,min,std
data.fillna(data['Price'].mean())
data.fillna(data['Price'].max())
data.fillna(data['Price'].min())
data.fillna(data['Price'].std())
# Out:
#                                  Order ID           Product Name  \
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 Laptop
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            Smart Watch
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           Refrigerator
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         Vacuum Cleaner
# 6    23d02906-c09f-428a-bc4c-6e5fc711997c                Shampoo
# ..                                    ...                    ...
# 494  dadeb50b-5778-423d-a467-1f2d667044d6                Shampoo
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  Machine Learning Book
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           Mobile Phone
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  Data Science Handbook
# 498  fdd68272-859d-46f6-a672-5e59e876e407        Washing Machine
#
#             Category    Price  Quantity  Order Date  Customer ID  \
# 1        Electronics   505.07         9  2023-02-22         2369
# ...

# %%
# Use forward or backward fill:
data.fillna(method='ffill')
data.fillna(method='bfill')
# Out:
#                                  Order ID           Product Name  \
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 Laptop
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            Smart Watch
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           Refrigerator
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         Vacuum Cleaner
# 6    23d02906-c09f-428a-bc4c-6e5fc711997c                Shampoo
# ..                                    ...                    ...
# 494  dadeb50b-5778-423d-a467-1f2d667044d6                Shampoo
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  Machine Learning Book
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           Mobile Phone
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  Data Science Handbook
# 498  fdd68272-859d-46f6-a672-5e59e876e407        Washing Machine
#
#             Category    Price  Quantity  Order Date  Customer ID  \
# 1        Electronics   505.07         9  2023-02-22         2369
# ...

# %% [markdown]
# ## Identify Duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Remove Duplicates

# %%
data.drop_duplicates()
# Out:
#                                  Order ID           Product Name  \
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 Laptop
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            Smart Watch
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           Refrigerator
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         Vacuum Cleaner
# 6    23d02906-c09f-428a-bc4c-6e5fc711997c                Shampoo
# ..                                    ...                    ...
# 494  dadeb50b-5778-423d-a467-1f2d667044d6                Shampoo
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  Machine Learning Book
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           Mobile Phone
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  Data Science Handbook
# 498  fdd68272-859d-46f6-a672-5e59e876e407        Washing Machine
#
#             Category    Price  Quantity  Order Date  Customer ID  \
# 1        Electronics   505.07         9  2023-02-22         2369
# ...

# %% [markdown]
# ## Type Chengein

# %%
data['Price'].astype(str)
# Out:
# 1       505.07
# 2      2206.52
# 3       457.76
# 4      1203.32
# 6      2061.48
#         ...
# 494     822.29
# 495    2321.77
# 496    1728.35
# 497     4822.1
# 498    3293.29
# Name: Price, Length: 446, dtype: object

# %%
data['Order Date']=pd.to_datetime(data['Order Date'])

# %%
print(data.dtypes)
# Out:
# Order ID                object
# Product Name            object
# Category                object
# Price                  float64
# Quantity                 int64
# Order Date      datetime64[ns]
# Customer ID              int64
# Country                 object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 446 entries, 1 to 498
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      446 non-null    object
#  1   Product Name  446 non-null    object
#  2   Category      446 non-null    object
#  3   Price         446 non-null    float64
#  4   Quantity      446 non-null    int64
#  5   Order Date    446 non-null    datetime64[ns]
#  6   Customer ID   446 non-null    int64
#  7   Country       446 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 31.4+ KB

# %% [markdown]
# ## Column Operations

# %%
# new Column add kar ne ki leyi
data['Bonus']=data['Price']*10

# %%
# Column rename
data.rename({'Product Name':'Product_Name'},inplace=True)

# %%
# drop the column
data.drop('Bonus',axis=1,inplace=True)

# %%
#Column ko Split Karna
#df[['First_Name', 'Last_Name']] = df['Full_Name'].str.split(' ', expand=True)

# %%
#Column Merge Karna
#df['Full_Name'] = df['First_Name'] + ' ' + df['Last_Name']

# %%
#Column ke Unique Values Check Karna
data['Category'].unique()
# Out:
# array(['Clothing', 'Electronics', 'Home Appliances', 'Beauty', 'Books'],
#       dtype=object)

# %%
data['Category'].nunique() # count dega category ka
# Out:
# 5

# %%
#Column ke Value Counts
data['Category'].value_counts() # har category me kitne order hui hai
# Out:
# Category
# Clothing           106
# Home Appliances    100
# Beauty              98
# Books               98
# Electronics         97
# Name: count, dtype: int64

# %%
data['Price'].value_counts(bins=5) # price ko 5 bins me divide karke count karega
# Out:
# (204.463, 1166.432]     112
# (1166.432, 2123.614]     98
# (4037.978, 4995.16]      96
# (3080.796, 4037.978]     88
# (2123.614, 3080.796]     77
# Name: count, dtype: int64

# %% [markdown]
# ## Row Operations

# %%
# row select kar ne ki leyi
data.iloc[2] # third row ka data
# Out:
# Order ID        7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d
# Product Name                             Smart Watch
# Category                                 Electronics
# Price                                        2206.52
# Quantity                                           1
# Order Date                                2023-05-19
# Customer ID                                     3187
# Country                                        Nepal
# Bonus                                        22065.2
# Name: 2, dtype: object

# %%
#  Row Select Karna (Condition ke Basis Par)
data[data['Price']>10000]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product Name, Category, Price, Quantity, Order Date, Customer ID, Country, Bonus]
# Index: []

# %%
#  Row Delete Karna
data.drop(index=2,inplace=True)

# %% [markdown]
# ## Split The columns

# %%
# order date to year split
pd.to_datetime(data['Order Date']).dt.year
# Out:
# 1      2023
# 2      2023
# 3      2023
# 4      2023
# 6      2023
#        ...
# 494    2023
# 495    2023
# 496    2023
# 497    2023
# 498    2023
# Name: Order Date, Length: 446, dtype: int32

# %%
# order date to month split
pd.to_datetime(data['Order Date']).dt.month
# Out:
# 1       2
# 2       5
# 3       3
# 4       5
# 6       6
#        ..
# 494     8
# 495     2
# 496     6
# 497    12
# 498     4
# Name: Order Date, Length: 446, dtype: int32

# %%
# order date to day split
pd.to_datetime(data['Order Date']).dt.day
# Out:
# 1      22
# 2      19
# 3       4
# 4      30
# 6      29
#        ..
# 494    30
# 495    17
# 496     4
# 497    19
# 498     1
# Name: Order Date, Length: 446, dtype: int32

# %% [markdown]
# ##  Text Cleaning

# %%
data['Product Name'] = data['Product Name'].str.lower().str.strip()

# %%
data['Product Name'] = data['Product Name'].str.upper().str.strip()

# %%
data
# Out:
#                                  Order ID           Product Name  \
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 LAPTOP
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            SMART WATCH
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           REFRIGERATOR
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         VACUUM CLEANER
# 6    23d02906-c09f-428a-bc4c-6e5fc711997c                SHAMPOO
# ..                                    ...                    ...
# 494  dadeb50b-5778-423d-a467-1f2d667044d6                SHAMPOO
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  MACHINE LEARNING BOOK
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           MOBILE PHONE
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  DATA SCIENCE HANDBOOK
# 498  fdd68272-859d-46f6-a672-5e59e876e407        WASHING MACHINE
#
#             Category    Price  Quantity Order Date  Customer ID  \
# 1        Electronics   505.07         9 2023-02-22         2369
# ...

# %%
data['Sales']=data['Price']*data['Quantity']

# %%
data
# Out:
#                                  Order ID           Product Name  \
# 1    275052d1-0592-40e0-8327-25019a3f99d3                 LAPTOP
# 2    7c89c3a8-6e2e-4a7d-ab00-f2934a1e5f6d            SMART WATCH
# 3    5dfc62d6-3bde-4dba-845b-c4ee8c4a71e6           REFRIGERATOR
# 4    eaeac001-bb18-4cbb-b490-1d407a03c886         VACUUM CLEANER
# 6    23d02906-c09f-428a-bc4c-6e5fc711997c                SHAMPOO
# ..                                    ...                    ...
# 494  dadeb50b-5778-423d-a467-1f2d667044d6                SHAMPOO
# 495  f90d7b23-10b1-4e2c-bc6d-78541151b392  MACHINE LEARNING BOOK
# 496  29baf274-4dda-449a-8176-7f40e4fc186e           MOBILE PHONE
# 497  e0c4c1e4-53e1-44a5-b73c-9c9ac5b52a71  DATA SCIENCE HANDBOOK
# 498  fdd68272-859d-46f6-a672-5e59e876e407        WASHING MACHINE
#
#             Category    Price  Quantity Order Date  Customer ID  \
# 1        Electronics   505.07         9 2023-02-22         2369
# ...

# %%
top_country=data.groupby('Country')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
top_country
# Out:
# Country
# Kyrgyz Republic            109103.25
# Sweden                     106129.16
# Bulgaria                    94262.69
# Israel                      91809.77
# Anguilla                    88410.79
# Aruba                       84219.55
# Cocos (Keeling) Islands     84188.54
# Equatorial Guinea           83701.15
# Bahrain                     82971.37
# Norfolk Island              82667.93
# Name: Sales, dtype: float64
